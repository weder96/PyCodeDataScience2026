# %%
# %pip install pandas

# %%
# %pip install requests

# %% [markdown]
# # Knowledge 3 - Biblioteca requests e JSON

# %%
import requests
import json
import pandas as pd

# %% [markdown]
# # Método GET

# %%
info_google = requests.get("https://www.google.com.br/") #não pode faltar o "https"

print(info_google)

# %% [markdown]
# ## Respostas de um servidor
#
# <br>
#
# ![image.png](attachment:image.png)
#
#
# https://developer.mozilla.org/pt-BR/docs/Web/HTTP/Status

# %%
#print(info_google.text)
#print(info_google.json())
print(info_google.headers) #isso aqui é o cabeçalho.

# %% [markdown]
# # Exemplo: Banco Central

# %%
codigo = 432
dataInicial = '20/09/2025'
url_banco_central = f'https://api.bcb.gov.br/dados/serie/bcdata.sgs.{codigo}/dados?formato=json&dataInicial={dataInicial}'

# %%
dados_selic = requests.get(url_banco_central)

print(dados_selic.json())
# Out:
# [{'data': '20/09/2025', 'valor': '15.00'}, {'data': '21/09/2025', 'valor': '15.00'}, {'data': '22/09/2025', 'valor': '15.00'}, {'data': '23/09/2025', 'valor': '15.00'}, {'data': '24/09/2025', 'valor': '15.00'}, {'data': '25/09/2025', 'valor': '15.00'}, {'data': '26/09/2025', 'valor': '15.00'}, {'data': '27/09/2025', 'valor': '15.00'}, {'data': '28/09/2025', 'valor': '15.00'}, {'data': '29/09/2025', 'valor': '15.00'}, {'data': '30/09/2025', 'valor': '15.00'}, {'data': '01/10/2025', 'valor': '15.00'}, {'data': '02/10/2025', 'valor': '15.00'}, {'data': '03/10/2025', 'valor': '15.00'}, {'data': '04/10/2025', 'valor': '15.00'}, {'data': '05/10/2025', 'valor': '15.00'}, {'data': '06/10/2025', 'valor': '15.00'}, {'data': '07/10/2025', 'valor': '15.00'}, {'data': '08/10/2025', 'valor': '15.00'}, {'data': '09/10/2025', 'valor': '15.00'}, {'data': '10/10/2025', 'valor': '15.00'}, {'data': '11/10/2025', 'valor': '15.00'}, {'data': '12/10/2025', 'valor': '15.00'}, {'data': '13/10/2025', 'valor': '15.00'}, {'data': '14/10/2025', 'valor': '15.00'}, {'data': '15/10/2025', 'valor': '15.00'}, {'data': '16/10/2025', 'valor': '15.00'}, {'data': '17/10/2025', 'valor': '15.00'}, {'data': '18/10/2025', 'valor': '15.00'}, {'data': '19/10/2025', 'valor': '15.00'}, {'data': '20/10/2025', 'valor': '15.00'}, {'data': '21/10/2025', 'valor': '15.00'}, {'data': '22/10/2025', 'valor': '15.00'}, {'data': '23/10/2025', 'valor': '15.00'}, {'data': '24/10/2025', 'valor': '15.00'}, {'data': '25/10/2025', 'valor': '15.00'}, {'data': '26/10/2025', 'valor': '15.00'}, {'data': '27/10/2025', 'valor': '15.00'}, {'data': '28/10/2025', 'valor': '15.00'}, {'data': '29/10/2025', 'valor': '15.00'}, {'data': '30/10/2025', 'valor': '15.00'}, {'data': '31/10/2025', 'valor': '15.00'}, {'data': '01/11/2025', 'valor': '15.00'}, {'data': '02/11/2025', 'valor': '15.00'}, {'data': '03/11/2025', 'valor': '15.00'}, {'data': '04/11/2025', 'valor': '15.00'}, {'data': '05/11/2025', 'valor': '15.00'}, {'data': '06/11/2025', 'valor': '15.00'}, {'data': '07/11/2025', 'valor': '15.00'}, {'data': '08/11/2025', 'valor': '15.00'}, {'data': '09/11/2025', 'valor': '15.00'}, {'data': '10/11/2025', 'valor': '15.00'}, {'data': '11/11/2025', 'valor': '15.00'}, {'data': '12/11/2025', 'valor': '15.00'}, {'data': '13/11/2025', 'valor': '15.00'}, {'data': '14/11/2025', 'valor': '15.00'}, {'data': '15/11/2025', 'valor': '15.00'}, {'data': '16/11/2025', 'valor': '15.00'}, {'data': '17/11/2025', 'valor': '15.00'}, {'data': '18/11/2025', 'valor': '15.00'}, {'data': '19/11/2025', 'valor': '15.00'}, {'data': '20/11/2025', 'valor': '15.00'}, {'data': '21/11/2025', 'valor': '15.00'}, {'data': '22/11/2025', 'valor': '15.00'}, {'data': '23/11/2025', 'valor': '15.00'}, {'data': '24/11/2025', 'valor': '15.00'}, {'data': '25/11/2025', 'valor': '15.00'}, {'data': '26/11/2025', 'valor': '15.00'}, {'data': '27/11/2025', 'valor': '15.00'}, {'data': '28/11/2025', 'valor': '15.00'}, {'data': '29/11/2025', 'valor': '15.00'}, {'data': '30/11/2025', 'valor': '15.00'}, {'data': '01/12/2025', 'valor': '15.00'}, {'data': '02/12/2025', 'valor': '15.00'}, {'data': '03/12/2025', 'valor': '15.00'}, {'data': '04/12/2025', 'valor': '15.00'}, {'data': '05/12/2025', 'valor': '15.00'}, {'data': '06/12/2025', 'valor': '15.00'}, {'data': '07/12/2025', 'valor': '15.00'}, {'data': '08/12/2025', 'valor': '15.00'}, {'data': '09/12/2025', 'valor': '15.00'}, {'data': '10/12/2025', 'valor': '15.00'}, {'data': '11/12/2025', 'valor': '15.00'}, {'data': '12/12/2025', 'valor': '15.00'}, {'data': '13/12/2025', 'valor': '15.00'}, {'data': '14/12/2025', 'valor': '15.00'}, {'data': '15/12/2025', 'valor': '15.00'}, {'data': '16/12/2025', 'valor': '15.00'}, {'data': '17/12/2025', 'valor': '15.00'}, {'data': '18/12/2025', 'valor': '15.00'}, {'data': '19/12/2025', 'valor': '15.00'}, {'data': '20/12/2025', 'valor': '15.00'}, {'data': '21/12/2025', 'valor': '15.00'}, {'data': '22/12/2025', 'valor': '15.00'}, {'data': '23/12/2025', 'valor': '15.00'}, {'data':  ...

# %%
json_selic = dados_selic.json()

# %%
df = pd.DataFrame(json_selic)

df
# Out:
#            data  valor
# 0    20/09/2025  15.00
# 1    21/09/2025  15.00
# 2    22/09/2025  15.00
# 3    23/09/2025  15.00
# 4    24/09/2025  15.00
# ..          ...    ...
# 357  12/09/2026  14.00
# 358  13/09/2026  14.00
# 359  14/09/2026  14.00
# 360  15/09/2026  14.00
# 361  16/09/2026  14.00
#
# [362 rows x 2 columns]

# %% [markdown]
# # Método POST

# %%
info_google = requests.post("https://www.google.com.br/")

print(info_google)
# Out:
# <Response [405]>

# %% [markdown]
# # Biblioteca JSON
#
# * A única utilidade dessa biblioteca é transformar um Json em um dicionário ou um dicionário em um JSON.

# %%
dicionario_cotacoes = {"WEGE3": [20, 30, 40], "VALE3": [30, 45, 60]}

dicionario_cotacoes
# Out:
# {'WEGE3': [20, 30, 40], 'VALE3': [30, 45, 60]}

# %%
json_cotacoes = json.dumps(dicionario_cotacoes)

json_cotacoes
# Out:
# '{"WEGE3": [20, 30, 40], "VALE3": [30, 45, 60]}'

# %%
dicionario_cotacoes_pos_json = json.loads(json_cotacoes)

dicionario_cotacoes_pos_json
# Out:
# {'WEGE3': [20, 30, 40], 'VALE3': [30, 45, 60]}

# %% [markdown]
# # Exercícios
#
# * Exercício 133: Faça uma requisição GET pra API do banco central e extraia dados de inflação, sabendo que o código do IPCA é 433. Com o resultado da requisição, crie um dataframe.
# * Exercício 134: Faça uma requisição POST para a API do banco central e dê um print nas response.

# %%
#gabarito 133

codigo = 433

url_banco_central = f'https://api.bcb.gov.br/dados/serie/bcdata.sgs.{codigo}/dados?formato=json'

dados_ipca = requests.get(url_banco_central)

json_ipca = dados_ipca.json()

df_ipca = pd.DataFrame(json_ipca)

df_ipca

# %%
#gabarito 134

codigo = 433

url_banco_central = f'https://api.bcb.gov.br/dados/serie/bcdata.sgs.{codigo}/dados?formato=json'

response = requests.post(url_banco_central)

print(response)
