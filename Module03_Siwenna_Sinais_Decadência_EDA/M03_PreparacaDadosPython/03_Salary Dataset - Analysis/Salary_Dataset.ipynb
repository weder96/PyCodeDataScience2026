# %% [markdown]
# # Context
#
#
# Information Technology in India is a vast industry that comprises information technology services, consulting, and outsourcing. The IT industry accounted for 8% of India's GDP in 2020. The IT and BPM industry's revenue is estimated at US Dollar 194 billion in FY 2021, an increase of 2.3 % YoY. The domestic revenue of the IT industry is estimated at US Dollar 45 billion and export revenue is estimated at US Dollar 150 billion in FY 2021.
#
# The IT-BPM sector overall employs 4.5 million people as of March 2021. The Indian IT-BPM industry has the highest employee attrition rate. In recent years the industry has witnessed skyrocketing resignations cutting across the hierarchy. As a global outsourcing hub, the Indian IT industry is infamous for exploiting cheap labor. As the IT-BPM sector evolves, many are concerned that artificial intelligence (AI) will drive significant automation and destroy jobs in the coming years.
#
# The software industry includes businesses for the development, maintenance, and publication of software that are using different business models, mainly either "license/maintenance based" (on-premises) or "Cloud-based" (such as SaaS, PaaS, IaaS, MBaaS, MSaaS, DCaaS, etc.). The industry also includes software services, such as training, documentation, consulting, and data recovery.
#
# # Content
# This Dataset contains information of 22700+ Software Professionals with different features like their Salaries **(₹)**, Name of the Company, Company Rating, Number of times Salaries Reported, and Location of the Company.
#
# Structure of the Dataset
# Software Professional Salaries - 2022
# ├── Rating
#
# ├── Company Name
#
# ├── Job Title
#
#
# ├── Salary (Indian Rupee - ₹)
# ├── Salaries Reported
#
# ├── Location
#
# ├── Employment Status
#
# └── Job Roles
#
#
#
# Acknowledgements
# For more, please visit: ***https://www.glassdoor.co.in/***

# %%
# %pip install numpy
# %pip install pandas
# %pip install matplotlib
# %pip install seaborn
# %pip install plotly
# Out:
# Requirement already satisfied: numpy in /home/weder/Documentos/Projects/PyCodeDataScience2026/.venv/lib/python3.12/site-packages (2.5.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in /home/weder/Documentos/Projects/PyCodeDataScience2026/.venv/lib/python3.12/site-packages (3.0.5)
# Requirement already satisfied: numpy>=1.26.0 in /home/weder/Documentos/Projects/PyCodeDataScience2026/.venv/lib/python3.12/site-packages (from pandas) (2.5.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/weder/Documentos/Projects/PyCodeDataScience2026/.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/weder/Documentos/Projects/PyCodeDataScience2026/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in /home/weder/Documentos/Projects/PyCodeDataScience2026/.venv/lib/python3.12/site-packages (3.11.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/weder/Documentos/Projects/PyCodeDataScience2026/.venv/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/weder/Documentos/Projects/PyCodeDataScience2026/.venv/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in /home/weder/Documentos/Projects/PyCodeDataScience2026/.venv/lib/python3.12/site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/weder/Documentos/Projects/PyCodeDataScience2026/.venv/lib/python3.12/site-packages (from matplotlib) (1.5.1)
# Requirement already satisfied: numpy>=1.25 in /home/weder/Documentos/Projects/PyCodeDataScience2026/.venv/lib/python3.12/site-packages (from matplotlib) (2.5.2)
# Requirement already satisfied: packaging>=20.0 in /home/weder/Documentos/Projects/PyCodeDataScience2026/.venv/lib/python3.12/site-packages (from matplotlib) (26.3)
# Requirement already satisfied: pillow>=9 in /home/weder/Documentos/Projects/PyCodeDataScience2026/.venv/lib/python3.12/site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in /home/weder/Documentos/Projects/PyCodeDataScience2026/.venv/lib/python3.12/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/weder/Documentos/Projects/PyCodeDataScience2026/.venv/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/weder/Documentos/Projects/PyCodeDataScience2026/.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: seaborn in /home/weder/Documentos/Projects/PyCodeDataScience2026/.venv/lib/python3.12/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/weder/Documentos/Projects/PyCodeDataScience2026/.venv/lib/python3.12/site-packages (from seaborn) (2.5.2)
# Requirement already satisfied: pandas>=1.2 in /home/weder/Documentos/Projects/PyCodeDataScience2026/.venv/lib/python3.12/site-packages (from seaborn) (3.0.5)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/weder/Documentos/Projects/PyCodeDataScience2026/.venv/lib/python3.12/site-packages (from seaborn) (3.11.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/weder/Documentos/Projects/PyCodeDataScience2026/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/weder/Documentos/Projects/PyCodeDataScience2026/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in /home/weder/Documentos/Projects/PyCodeDataScience2026/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/weder/Documentos/Projects/PyCodeDataScience2026/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.1)
# Requirement already satisfied: packaging>=20.0 in /home/weder/Documentos/Projects/PyCodeDataScience2026/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.3)
# Requirement already satisfied: pillow>=9 in /home/weder/Documentos/Projects/PyCodeDataScience2026/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in /home/weder/Documentos/Projects/PyCodeDataScience2026/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/weder/Documentos/Projects/PyCodeDataScience2026/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/weder/Documentos/Projects/PyCodeDataScience2026/.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Collecting plotly
#   Downloading plotly-7.0.0-py3-none-any.whl.metadata (8.7 kB)
# Collecting narwhals>=1.15.1 (from plotly)
#   Downloading narwhals-2.25.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging in /home/weder/Documentos/Projects/PyCodeDataScience2026/.venv/lib/python3.12/site-packages (from plotly) (26.3)
# Downloading plotly-7.0.0-py3-none-any.whl (9.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 6.3 MB/s eta 0:00:0000:0100:010m
# Downloading narwhals-2.25.0-py3-none-any.whl (467 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 467.4/467.4 kB 7.4 MB/s eta 0:00:00ta 0:00:01
# Installing collected packages: narwhals, plotly
# Successfully installed narwhals-2.25.0 plotly-7.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# Importing all needed libraries
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

plt.style.use("fivethirtyeight")


print("All Modules & Settings Initialized 🚀")
# Out:
# All Modules & Settings Initialized 🚀

# %%
# Import the data
from urllib.request import urlretrieve 
URL = "./SalaryDataset.csv"
salary_data = pd.read_csv(URL)

print("Data Imported Successfully 🚀")
# Out:
# Data Imported Successfully 🚀

# %% [markdown]
# # Cleaning, Exploring, Visualizing & Playing with the data.
#
# I first did a bit of cleaning here and there.
#
# Deleting and adding etc.
#
# Then, did a bit of exploration and got to know my data.
#
# Finally, I visualised to get some insights from the data provided.
#
# Check it all out from below!
#
# Enjoy your code read 👍🏻

# %%
# First 5 rows of data
salary_data.head(5)
# Out:
#    Rating                      Company Name          Job Title   Salary  \
# 0     3.8                            Sasken  Android Developer   400000
# 1     4.5  Advanced Millennium Technologies  Android Developer   400000
# 2     4.0                         Unacademy  Android Developer  1000000
# 3     3.8                SnapBizz Cloudtech  Android Developer   300000
# 4     4.4            Appoids Tech Solutions  Android Developer   600000
#
#    Salaries Reported   Location Employment Status Job Roles
# 0                  3  Bangalore         Full Time   Android
# 1                  3  Bangalore         Full Time   Android
# 2                  3  Bangalore         Full Time   Android
# 3                  3  Bangalore         Full Time   Android
# 4                  3  Bangalore         Full Time   Android

# %%
# Last 5 rows of data
salary_data.tail(5)
# Out:
#        Rating             Company Name                 Job Title  Salary  \
# 22765     4.7         Expert Solutions             Web Developer  200000
# 22766     4.0  Nextgen Innovation Labs             Web Developer  300000
# 22767     4.1                  Fresher  Full Stack Web Developer  192000
# 22768     4.1                Accenture  Full Stack Web Developer  300000
# 22769     3.8          Thomson Reuters   Associate Web Developer  300000
#
#        Salaries Reported   Location Employment Status Job Roles
# 22765                  1  Bangalore         Full Time       Web
# 22766                  1  Bangalore         Full Time       Web
# 22767                 13  Bangalore         Full Time       Web
# 22768                  7  Bangalore         Full Time       Web
# 22769                  7  Bangalore         Full Time       Web

# %%
# What is the change of salary in different locations?
sns.set(rc={'figure.figsize':(15.7,9.27)})
sns.barplot(data=salary_data, x="Location", y="Salary", hue="Employment Status")
sns.lineplot(data=salary_data, x="Location", y="Salary", hue="Employment Status", linewidth=2.5, marker='o')

# Descriptions
plt.title("Change of Salary per Location and Employment Status")
plt.show()

# %%
# How does Salary change with rating and employment status?
sns.set(rc={'figure.figsize':(25.7,9.27)})
# figure_1 = sns.lineplot(data=salary_data, x="Employment Status", y="Salary", hue="Rating")
figure_1 = sns.barplot(data=salary_data, x="Employment Status", y="Salary", hue="Rating")
sns.move_legend(figure_1, "lower center", bbox_to_anchor=(.5, 1), ncol=21, title="Rating", frameon=False)

# Descriptions
plt.title("Change of Salary per Location and Employment Status")
plt.show()

# %%
# Change of Salary per Job Role and Employment Status
sns.relplot(col="Job Roles", y="Salary", kind="line",x='Employment Status', data=salary_data, color="#840032")

# Descriptions
plt.title("Change of Salary per Job Role and Employment Status")
plt.show()

# %%
# Frequency of Employment Status
salary_data["Employment Status"].value_counts().plot.line(color=["#00132d"], marker="o", markersize=12)
salary_data["Employment Status"].value_counts().plot.bar(color=["#3f004d", "#001e45"])

# Descriptions
plt.title("Frequency X Employment Status")
plt.xticks(rotation = 360)
plt.show()

# %%
# Frequency of Location
salary_data["Location"].value_counts().plot.bar(color=["#003049", "#6B2C39"])

salary_data["Location"].value_counts().plot.line(color=["#FCBF49"], marker="o", markersize=12)

# Descriptions
plt.title("Frequency X Location")
plt.show()

# %%
# Frequency of Job Roles
salary_data["Job Roles"].value_counts().plot.line(color=["#e07a5f"], marker="o", markersize=12)
salary_data["Job Roles"].value_counts().plot.bar(color=["#33032f", "#531253"])

# Descriptions
plt.title("Frequency X Job Roles")
plt.xticks(rotation = 360)
plt.show()

# %%
# How does Salary change with Employment status?
sns.set(rc={'figure.figsize':(25.7,9.27)})
figure_1 = sns.lineplot(data=salary_data, x="Employment Status", y="Salary", color="#0f4c5c")
figure_1 = sns.barplot(data=salary_data, x="Employment Status", y="Salary", color="#b1a7a6")

# Descriptions
plt.title("Salary VS Employment Status")
plt.show()
